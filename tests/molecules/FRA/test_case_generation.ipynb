# %%
from rdkit import Chem

# %%
mol = Chem.MolFromPDBFile('input.pdb')
mol

# %%
print(Chem.MolToSmiles(mol))
# Out:
# CC(O)NC1CCC(N2C(O)[C@@H]3[C@H]4CC[C@](NC(O)OCC(O)O)(CC4)[C@@H]3C2O)CC1

# %%
with open('output.smi') as f:
    smiles = f.read()
print(smiles)
# Out:
# CC(=O)Nc1ccc(cc1)N2C(=O)[C@@H]3C4CCC([C@@H]3C2=O)(CC4)NC(=O)OCC(=O)O

# %%
mol_gt = Chem.MolFromSmiles(smiles)
mol_gt
